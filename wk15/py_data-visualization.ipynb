# %% [markdown]
# # Jesus Bolivar
# ## Week 15 11/28/2023 - 11/30/2023
# ### Python - data visualization - making informative visualizations (using plots)

# %%
#The normal imports
import numpy as np
from numpy.random import randn
import pandas as pd

# These are the plotting modules and libraries we'll use:
import matplotlib as mpl
import matplotlib.pyplot as plt

# Command so that plots appear in the iPython Notebook
# %matplotlib inline

# %%
data = np.array([1,2,3,4,5,6,3,1,2,3,4,5])*100
data
# Out:
# array([100, 200, 300, 400, 500, 600, 300, 100, 200, 300, 400, 500])

# %%
plt.plot(data)

# %%
data = randn(20)
df = pd.DataFrame(data)
df
# Out:
#            0
# 0   0.937110
# 1  -0.519186
# 2   0.043811
# 3   3.668105
# 4  -0.416092
# 5   0.445091
# 6  -0.698514
# 7  -0.348696
# 8  -0.760340
# 9   0.961565
# 10 -0.657901
# 11  0.685518
# 12 -0.262992
# 13  0.384198
# 14 -1.896317
# 15 -0.713953
# 16  1.878376
# 17 -2.391597
# 18 -0.227022
# 19 -0.864492

# %%
plt.plot(df)

# %%
dataset1 = randn(100)
dataset1
# Out:
# array([-1.00525087e-01, -2.58221502e+00, -1.48669074e+00,  1.50123369e+00,
#         7.91760039e-01, -2.91064393e-01,  3.76538875e-01,  8.23434002e-01,
#        -2.30063559e-02, -4.84838369e-01,  4.59780333e-01,  1.20126589e+00,
#         9.60033367e-01,  1.81800248e-03,  7.06822623e-01,  1.28963964e+00,
#        -1.17494939e-01, -1.18330885e-01, -1.17679145e-01, -7.80459432e-01,
#        -1.37151622e+00,  1.29808603e+00,  5.83193113e-01,  1.70348810e-01,
#         7.45494121e-01, -5.07088110e-01, -8.06131650e-01, -1.09069097e+00,
#        -1.56987537e+00, -6.71903405e-01, -4.21896946e-01, -3.43492308e-01,
#         1.47036758e+00,  3.02413040e-01, -1.56716151e+00, -1.04692294e+00,
#         3.73457014e-01,  6.22521136e-01,  1.14144436e+00, -1.18931768e+00,
#         1.06644314e+00,  2.76022376e-01, -5.75164513e-01,  5.18910735e-01,
#        -5.03982068e-01, -1.01903771e-02,  8.72383169e-01,  4.56587878e-01,
#         6.46042404e-01, -9.59735375e-02,  1.89769696e-02, -1.22332993e+00,
#         8.93678612e-01, -1.72565748e-01, -1.09170169e+00, -1.67754180e+00,
#        -1.44599310e+00, -2.59430871e-01,  7.62913381e-01, -1.70752053e+00,
#         4.67013953e-01,  6.05108126e-01,  3.67621034e-01, -3.61609103e-01,
#        -1.44061165e+00,  6.50399383e-01,  1.42354335e-01,  2.26480504e+00,
#        -4.50289925e-02,  5.85188822e-01,  1.30832243e+00, -4.55479637e-01,
#        -1.28108314e+00, -8.91692033e-01,  9.90479598e-01,  1.92328371e-01,
#        -4.97372592e-01, -3.25847787e-01, -7.46869179e-01,  3.15773817e-02,
#        -4.37205062e-01,  3.24122932e+00,  9.07580841e-02,  2.74300321e-01,
#        -8.76579774e-01, -1.21828078e+00, -8.19684594e-01,  4.03078569e-01,
#         2.19283278e-02, -3.87768105e-01, -1.52215776e+00, -1.34379036e+00,
#         5.47342002e-01, -4.39023416e-02,  4.76791611e-01,  1.27366183e+00,
#        -6.36641980e-01,  8.53889476e-01,  5.26823717e-01,  6.49961120e-01])

# %%
plt.hist(dataset1)
# Out:
# (array([ 1.,  8., 11., 20., 21., 26., 10.,  1.,  1.,  1.]),
#  array([-2.58221502, -1.99987059, -1.41752615, -0.83518172, -0.25283729,
#          0.32950715,  0.91185158,  1.49419602,  2.07654045,  2.65888488,
#          3.24122932]),
#  <a list of 10 Patch objects>)

# %%
dataset2 = randn(100)
plt.hist(dataset2, color='indianred')
# Out:
# (array([ 5.,  5., 10., 13.,  5., 20., 13., 16.,  8.,  5.]),
#  array([-2.11347193, -1.69393444, -1.27439695, -0.85485946, -0.43532197,
#         -0.01578448,  0.40375301,  0.8232905 ,  1.24282799,  1.66236549,
#          2.08190298]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(dataset1, color='indianred', alpha)
# Out:
#   File "<ipython-input-13-38b7a642d60b>", line 1
#     plt.hist(dataset1, color='indianred', alpha)
#                                          ^
# SyntaxError: positional argument follows keyword argument

# %%
#Figures and subplots
fig = plt.figure()

# %%
fig = plt.figure(figsize=(2,4), dpi=100)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)
plt.plot(randn(5))

# %%
fig = plt.figure(figsize = (5,5),dpi=100)
ax1 = fig.add_subplot(2,2,1)
plt.plot(randn(5))
ax2 = fig.add_subplot(2,2,2)
plt.plot([-1,0.5,0,1.23])
ax3 = fig.add_subplot(2,2,3)
plt.plot([1.5,3.5,-2,1.6])
ax4 = fig.add_subplot(2,2,4)
plt.plot(randn(5))

# %%
fig1 = plt.figure()
ax1 = fig1.add_axes((0,0,.4,.4)) #add_axes ([left,bottom, width,height])

# %%
fig1 = plt.figure()
ax1 = fig1.add_axes((0,0,.4,.4))
ax2 = fig1.add_axes((.25,0.25,.3,.3))

# %%
fig1 = plt.figure()
ax1 = fig1.add_axes((0,0,.4,.4))
ax2 = fig1.add_axes((0,.7,.6,.6))

# %%
dataset = randn(50).cumsum()
dataset
# Out:
# array([-1.26234904, -2.15447046, -1.39977761, -0.81762509,  0.52605424,
#         1.13062928, -0.02330582, -0.98686285, -1.52010071, -0.88936373,
#        -0.89701347, -1.35612265, -1.80056593, -0.45569033,  1.45253573,
#         2.12014467,  2.20503041,  2.53756454,  3.22353296,  3.89097521,
#         3.98249427,  3.03873157,  3.59745986,  3.40778732,  0.69665592,
#         0.77707437,  1.65262304,  2.71048738,  1.45066358,  1.48631581,
#         2.47163778,  3.174214  ,  3.33323746,  5.40422969,  6.00891238,
#         5.77504911,  6.58194504,  6.28470963,  6.93618577,  5.07558463,
#         5.02066222,  5.87158641,  5.34516066,  6.36189869,  6.66846826,
#         6.80641614,  7.08482791,  5.97001208,  5.74995275,  4.55090407])

# %%
fig3=plt.figure()
ax1 = fig3.add_subplot(2,1,1)
ax2 = fig3.add_subplot(2,1,2)

ax1.plot(dataset, 'k-')
ax2.plot(dataset, 'k--')

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax1.hist(randn(100), bins=20, color='k',alpha=0.25)

ax2 = fig.add_subplot(2,2,2)
ax2.scatter(np.arange(30), randn(30).cumsum())

ax3 = fig.add_subplot(2,2,3)
ax3.plot(dataset, 'k--')

# %%
#colors, markers, and line styles
plt.plot(randn(30),'ko--')

# %%
plt.plot(4*randn(30), color='k',linestyle='dotted',marker='o') #'dashed', 'solid',

# %%
plt.plot(4*randn(30), color='k',linestyle='solid',marker='o')

# %%
plt.plot(4*randn(30), color='k',linestyle='dashed',marker='o')

# %%
df1 = pd.DataFrame(randn(30).cumsum())
df1
# Out:
#            0
# 0   1.136121
# 1   2.361068
# 2   1.890514
# 3   1.000393
# 4  -1.005116
# 5  -1.227046
# 6  -0.392398
# 7   0.342710
# 8  -0.491149
# 9   0.537717
# 10 -0.609996
# 11 -1.242879
# 12 -1.330900
# 13  1.284523
# 14 -1.486166
# 15 -1.679504
# 16 -1.342483
# 17 -0.393259
# 18 -0.324879
# 19 -1.069723
# 20 -1.257159
# 21 -1.550784
# 22 -2.821761
# 23 -4.279673
# 24 -3.072671
# 25 -3.587077
# 26 -4.593788
# 27 -3.107773
# 28 -1.527094
# 29 -2.044547

# %%
#plot with pandas
df1.plot()

# %%
plt.plot(df1)

# %%
plt.plot(df1, drawstyle='steps-post')

# %%
plt.plot(df1, 'k--')
plt.plot(df1, 'k', drawstyle='steps-post')

# %%
data = randn(50).cumsum()
data
# Out:
# array([  0.8005881 ,   0.11355396,   0.06692846,  -0.274713  ,
#         -1.02816182,  -0.74852821,  -1.94619706,  -0.82207964,
#         -1.85771579,  -1.35548297,  -3.08688115,  -5.72776058,
#         -5.56389923,  -5.38512196,  -4.31135932,  -5.2521978 ,
#         -4.6344455 ,  -4.13137815,  -3.76197794,  -6.00322335,
#         -6.70453581,  -7.97266837,  -7.26650445,  -5.78304973,
#         -5.9504876 ,  -6.55243783,  -7.79347749,  -6.52487519,
#         -7.16964211,  -8.05213315,  -7.53028141,  -8.79878074,
#         -7.99061085,  -6.98582184,  -8.15575412,  -8.43883608,
#         -9.07222382,  -9.41509554, -10.5587533 , -10.0359121 ,
#         -9.73297411, -10.14751392, -12.49633702, -10.70429995,
#         -9.78301704, -11.16267604, -10.03679761,  -8.40372968,
#         -6.62997222,  -7.1705973 ])

# %%
#using label
plt.plot(data, 'k--', label='Dashed-Line')
plt.plot(data, 'k-', drawstyle='steps-post', label='[steps-post]')
plt.legend(loc='best')
# place a legend on the [upper left, lower left, center right]

# %%
d = ('coll', randn(30).cumsum(), 'col2', randn(30).cumsum())
df1
#df2
# Out:
#            0
# 0   1.136121
# 1   2.361068
# 2   1.890514
# 3   1.000393
# 4  -1.005116
# 5  -1.227046
# 6  -0.392398
# 7   0.342710
# 8  -0.491149
# 9   0.537717
# 10 -0.609996
# 11 -1.242879
# 12 -1.330900
# 13  1.284523
# 14 -1.486166
# 15 -1.679504
# 16 -1.342483
# 17 -0.393259
# 18 -0.324879
# 19 -1.069723
# 20 -1.257159
# 21 -1.550784
# 22 -2.821761
# 23 -4.279673
# 24 -3.072671
# 25 -3.587077
# 26 -4.593788
# 27 -3.107773
# 28 -1.527094
# 29 -2.044547

# %%
plt.plot(df2['coll'], 'k.', label='coll')
plt.plot(df2['coll'], 'k.', label='coll')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-46879573d898> in <module>
# ----> 1 plt.plot(df2['coll'], 'k.', label='coll')
#       2 plt.plot(df2['coll'], 'k.', label='coll')
#
# NameError: name 'df2' is not defined

# %%
df2['coll'].plot.bar()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-b21d8b9c883e> in <module>
# ----> 1 df2['coll'].plot.bar()
#
# NameError: name 'df2' is not defined

# %%
df2['col2'].plot.bar()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-8aa7be129c80> in <module>
# ----> 1 df2['col2'].plot.bar()
#
# NameError: name 'df2' is not defined

# %%
#Ticks, labels, and legends
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(randn(1000).cumsum())

# %%
ax.set_xticks([0,250,500,750,1000])

ax.set_ticklabels(['one','two','three','four','five'], rotation=30, fontsize='small')

ax.set_title('My first Matplotlip Plot with Ticks')

ax.set_xlabel('Stages')
ax.set_ylabel('Values')

fig
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-e42bcdd28d82> in <module>
#       1 ax.set_xticks([0,250,500,750,1000])
#       2
# ----> 3 ax.set_ticklabels(['one','two','three','four','five'], rotation=30, fontsize='small')
#       4
#       5 ax.set_title('My first Matplotlip Plot with Ticks')
#
# AttributeError: 'AxesSubplot' object has no attribute 'set_ticklabels'

# %%
#Use dictionary for title, xlabel and ylabel
props = {'title: My first matplotlip Plot with ticks',
        xlabel: 'stages',
        ylabel}
# Out:
#   File "<ipython-input-51-a30f4886bd1f>", line 3
#     xlabel: 'stages',
#           ^
# SyntaxError: invalid syntax

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)

ax.plot(randn(1000).cumsum(), 'k-', label='One')
ax.plot(randn(1000).cumsum(), 'k-', label='two')
ax.plot(randn(1000).cumsum(), 'k-', label='Three')

ax.legend(loc='best')

# %%
#saving a figure in an image file
fig.savefig('fig1.png')
